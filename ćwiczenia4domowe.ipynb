# %% [markdown]
# <a href="https://colab.research.google.com/github/janzaw04/myTestRep/blob/main/%C4%87wiczenia4domowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Trains a simple deep NN on the MNIST dataset.

Gets to 99.6% test accuracy after 40 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.optimizers import RMSprop, Adam, Adadelta

from keras.utils.vis_utils import plot_model
from IPython.display import Image 
from keras.preprocessing.image import ImageDataGenerator

from keras.callbacks import EarlyStopping

# install optuna
! pip install optuna

import optuna


batch_size = 128
num_classes = 10
epochs = 50

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train0), (x_test, y_test0) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)



x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train0, num_classes)
y_test = keras.utils.to_categorical(y_test0, num_classes)
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.6/dist-packages (2.4.0)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from optuna) (1.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from optuna) (1.19.5)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.6/dist-packages (from optuna) (4.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (20.8)
# Requirement already satisfied: cliff in /usr/local/lib/python3.6/dist-packages (from optuna) (3.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from optuna) (4.41.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (1.3.22)
# Requirement already satisfied: cmaes>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from optuna) (0.7.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.6/dist-packages (from optuna) (1.5.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (5.5.1)
# Requirement already satisfied: cmd2!=0.8.3,>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (1.4.0)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (3.13)
# Requirement already satisfied: PrettyTable<0.8,>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cliff->optuna) (0.7.2)
# Requirement already satisfied: python-editor>=0.3 in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (1.0.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (1.1.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from alembic->optuna) (2.8.1)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: colorama>=0.3.7 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (0.4.4)
# Requirement already satisfied: importlib-metadata>=1.6.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (3.3.0)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (1.8.1)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.6/dist-packages (from cmd2!=0.8.3,>=0.8.0->cliff->optuna) (20.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic->optuna) (1.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil->alembic->optuna) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.6.0; python_version < "3.8"->cmd2!=0.8.3,>=0.8.0->cliff->optuna) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.6.0; python_version < "3.8"->cmd2!=0.8.3,>=0.8.0->cliff->optuna) (3.4.0)
# 60000 train samples
# 10000 test samples

# %%
N_TRAIN_EXAMPLES = 1000 #3000
N_TEST_EXAMPLES = 10000
x_train = x_train[:N_TRAIN_EXAMPLES]
x_test = x_test[:N_TEST_EXAMPLES]
y_train = y_train[:N_TRAIN_EXAMPLES]
y_test = y_test[:N_TEST_EXAMPLES]

# %%
def c_model():
  # Our old fully connected (dense) network
  #model = Sequential()
  #model.add(Dense(512, activation='relu', input_shape=(784,)))
  #model.add(Dropout(0.2))
  #model.add(Dense(512, activation='relu'))
  #model.add(Dropout(0.2))
  #model.add(Dense(512, activation='relu'))
  #model.add(Dropout(0.2))
  #model.add(Dense(num_classes, activation='softmax'))
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
  model.add(Conv2D(64, (3, 3), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  model.add(Flatten())
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(num_classes, activation='softmax'))

  return model

# %%
def objective(trial):
  
  rotation_range=trial.suggest_uniform('rotation_range', .00,30)
  zoom_range=trial.suggest_uniform('zoom_range', .00,0.30)
  shift_range=trial.suggest_uniform('shift_range', .00,0.20)
  
  datagen = ImageDataGenerator( 
    rotation_range=rotation_range,
    width_shift_range=shift_range,
    height_shift_range=shift_range,
    zoom_range=zoom_range
    )

  model = c_model()

  from keras.callbacks import EarlyStopping

  model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])
  
  e_s=EarlyStopping(monitor='val_accuracy', patience=12, verbose=1)

  history = model.fit(datagen.flow(x_train, y_train,
                    batch_size=batch_size),
                    epochs=epochs,
                    batch_size=batch_size,
                    verbose=0,
                    validation_data=(x_test, y_test), 
                    callbacks=[e_s])

  score = model.evaluate(x_test, y_test,verbose=0)

  return score[1]

# %%
study = optuna.create_study(direction='maximize', pruner=optuna.pruners.MedianPruner(), sampler=optuna.samplers.TPESampler() )
study.optimize(objective, n_trials=30, timeout=1200)
# Out:
# [I 2021-01-26 14:42:29,535] A new study created in memory with name: no-name-9a222eb6-5cd1-4f86-80a9-f2d4b7275498
# [I 2021-01-26 14:42:56,763] Trial 0 finished with value: 0.9613999724388123 and parameters: {'rotation_range': 12.180755301998335, 'zoom_range': 0.08852467516799481, 'shift_range': 0.16426539224443726}. Best is trial 0 with value: 0.9613999724388123.
# [I 2021-01-26 14:43:23,590] Trial 1 finished with value: 0.9672999978065491 and parameters: {'rotation_range': 17.756820665516326, 'zoom_range': 0.005867021433375741, 'shift_range': 0.1683976735547102}. Best is trial 1 with value: 0.9672999978065491.
# [I 2021-01-26 14:43:50,410] Trial 2 finished with value: 0.9695000052452087 and parameters: {'rotation_range': 1.7570060057336268, 'zoom_range': 0.024623568835570552, 'shift_range': 0.07745419317528689}. Best is trial 2 with value: 0.9695000052452087.
# [I 2021-01-26 14:44:17,270] Trial 3 finished with value: 0.9545999765396118 and parameters: {'rotation_range': 6.782790516545116, 'zoom_range': 0.12164808342073219, 'shift_range': 0.1986777151740996}. Best is trial 2 with value: 0.9695000052452087.
# [I 2021-01-26 14:44:44,313] Trial 4 finished with value: 0.9699000120162964 and parameters: {'rotation_range': 9.067891289769822, 'zoom_range': 0.12835104530690214, 'shift_range': 0.07554279166364608}. Best is trial 4 with value: 0.9699000120162964.
# [I 2021-01-26 14:45:10,743] Trial 5 finished with value: 0.9722999930381775 and parameters: {'rotation_range': 9.79121769162134, 'zoom_range': 0.05322051238572482, 'shift_range': 0.04953048418080652}. Best is trial 5 with value: 0.9722999930381775.
# [I 2021-01-26 14:45:37,482] Trial 6 finished with value: 0.9753000140190125 and parameters: {'rotation_range': 17.306407486371203, 'zoom_range': 0.04779323539462704, 'shift_range': 0.05846979880741197}. Best is trial 6 with value: 0.9753000140190125.
# [I 2021-01-26 14:46:04,283] Trial 7 finished with value: 0.9692000150680542 and parameters: {'rotation_range': 15.073189429926616, 'zoom_range': 0.04894052781125021, 'shift_range': 0.039254082288704355}. Best is trial 6 with value: 0.9753000140190125.
# [I 2021-01-26 14:46:31,232] Trial 8 finished with value: 0.9796000123023987 and parameters: {'rotation_range': 29.583983070721573, 'zoom_range': 0.24717132670100134, 'shift_range': 0.09250810682301708}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:46:58,107] Trial 9 finished with value: 0.9677000045776367 and parameters: {'rotation_range': 10.251962561502541, 'zoom_range': 0.10535341234612179, 'shift_range': 0.016650482430704463}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:47:24,967] Trial 10 finished with value: 0.9768999814987183 and parameters: {'rotation_range': 29.908080693488078, 'zoom_range': 0.25959577666130124, 'shift_range': 0.12173249008120796}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:47:51,887] Trial 11 finished with value: 0.9747999906539917 and parameters: {'rotation_range': 29.44012868593842, 'zoom_range': 0.26372509817410705, 'shift_range': 0.11881582974772785}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:48:18,340] Trial 12 finished with value: 0.9787999987602234 and parameters: {'rotation_range': 29.17652951405823, 'zoom_range': 0.26129368342253056, 'shift_range': 0.11673636802076703}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:48:45,767] Trial 13 finished with value: 0.9711999893188477 and parameters: {'rotation_range': 24.20141009274481, 'zoom_range': 0.20706959333013314, 'shift_range': 0.12098742580328883}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:49:12,785] Trial 14 finished with value: 0.9765999913215637 and parameters: {'rotation_range': 23.90955645298753, 'zoom_range': 0.19618055990686012, 'shift_range': 0.09276387804340616}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:49:39,798] Trial 15 finished with value: 0.97079998254776 and parameters: {'rotation_range': 25.777901599801385, 'zoom_range': 0.21698039622118692, 'shift_range': 0.14524055915778852}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:50:07,112] Trial 16 finished with value: 0.9743000268936157 and parameters: {'rotation_range': 21.213633903758463, 'zoom_range': 0.29189215813145764, 'shift_range': 0.10164214239050283}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:50:34,547] Trial 17 finished with value: 0.9678999781608582 and parameters: {'rotation_range': 29.939847006704753, 'zoom_range': 0.2996828627645348, 'shift_range': 0.152179185382737}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:51:01,564] Trial 18 finished with value: 0.9614999890327454 and parameters: {'rotation_range': 28.13408397981756, 'zoom_range': 0.1727392261070178, 'shift_range': 0.19494178550242303}. Best is trial 8 with value: 0.9796000123023987.
# [I 2021-01-26 14:51:28,419] Trial 19 finished with value: 0.98089998960495 and parameters: {'rotation_range': 20.84539273651651, 'zoom_range': 0.24533730778051377, 'shift_range': 0.0997630597325534}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:51:55,387] Trial 20 finished with value: 0.9753000140190125 and parameters: {'rotation_range': 19.087173034635118, 'zoom_range': 0.24227273053513798, 'shift_range': 0.0070503872648386146}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:52:22,685] Trial 21 finished with value: 0.9778000116348267 and parameters: {'rotation_range': 26.715470997191346, 'zoom_range': 0.24211179063898902, 'shift_range': 0.09992711236931119}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:52:49,659] Trial 22 finished with value: 0.9786999821662903 and parameters: {'rotation_range': 21.091283855742603, 'zoom_range': 0.27664317673915295, 'shift_range': 0.13556119383500656}. Best is trial 19 with value: 0.98089998960495.
# Epoch 00050: early stopping
# [I 2021-01-26 14:53:16,809] Trial 23 finished with value: 0.974399983882904 and parameters: {'rotation_range': 22.857801128436726, 'zoom_range': 0.176483146207828, 'shift_range': 0.08663838214392537}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:53:43,780] Trial 24 finished with value: 0.9703999757766724 and parameters: {'rotation_range': 27.08840772106477, 'zoom_range': 0.22934377397717653, 'shift_range': 0.10601101768201722}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:54:11,300] Trial 25 finished with value: 0.9750999808311462 and parameters: {'rotation_range': 25.04213302643641, 'zoom_range': 0.1857024994632272, 'shift_range': 0.06512393440199642}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:54:37,841] Trial 26 finished with value: 0.9718000292778015 and parameters: {'rotation_range': 20.91708085528086, 'zoom_range': 0.2827712501150169, 'shift_range': 0.1323339456575203}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:55:05,019] Trial 27 finished with value: 0.972000002861023 and parameters: {'rotation_range': 27.602046936633748, 'zoom_range': 0.1521609042778676, 'shift_range': 0.11114312016165445}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:55:31,797] Trial 28 finished with value: 0.9700999855995178 and parameters: {'rotation_range': 14.380241251349341, 'zoom_range': 0.2524207013864901, 'shift_range': 0.08558208648991528}. Best is trial 19 with value: 0.98089998960495.
# [I 2021-01-26 14:55:58,664] Trial 29 finished with value: 0.9672999978065491 and parameters: {'rotation_range': 29.518308115784293, 'zoom_range': 0.22310636121160557, 'shift_range': 0.17350637982397737}. Best is trial 19 with value: 0.98089998960495.

# %%
print("Number trials: {}".format(len(study.trials)))
print("Best trial:")
trial=study.best_trial
print("Value: {}".format(trial.value))
print("Params")
for key, value in trial.params.items():
  print("  {}:{}  ".format(key, value))
# Out:
# Number trials: 30
# Best trial:
# Value: 0.98089998960495
# Params
#   rotation_range:20.84539273651651
#   zoom_range:0.24533730778051377
#   shift_range:0.0997630597325534

# %%
rotation_range=trial.params.get('rotation_range')
zoom_range=trial.params.get('zoom_range')
shift_range=trial.params.get('shift_range')

  
datagen = ImageDataGenerator( 
    rotation_range=rotation_range,
    width_shift_range=shift_range,
    height_shift_range=shift_range,
    zoom_range=zoom_range
    )

model = c_model()

from keras.callbacks import EarlyStopping

model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

e_s=EarlyStopping(monitor='val_accuracy',patience=12,verbose=1)

history = model.fit(datagen.flow(x_train, y_train,
                    batch_size=batch_size),
                    epochs=epochs,
                    batch_size=batch_size,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks=[e_s])
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 94ms/step - loss: 2.3020 - accuracy: 0.1104 - val_loss: 2.2196 - val_accuracy: 0.3849
# Epoch 2/50
# 8/8 [==============================] - 1s 74ms/step - loss: 2.2346 - accuracy: 0.2009 - val_loss: 1.8040 - val_accuracy: 0.5725
# Epoch 3/50
# 8/8 [==============================] - 1s 74ms/step - loss: 2.0232 - accuracy: 0.2992 - val_loss: 1.1694 - val_accuracy: 0.7536
# Epoch 4/50
# 8/8 [==============================] - 1s 71ms/step - loss: 1.7357 - accuracy: 0.4134 - val_loss: 0.8736 - val_accuracy: 0.7905
# Epoch 5/50
# 8/8 [==============================] - 1s 75ms/step - loss: 1.5493 - accuracy: 0.4597 - val_loss: 0.6594 - val_accuracy: 0.8547
# Epoch 6/50
# 8/8 [==============================] - 1s 70ms/step - loss: 1.4000 - accuracy: 0.5256 - val_loss: 0.4898 - val_accuracy: 0.8822
# Epoch 7/50
# 8/8 [==============================] - 1s 73ms/step - loss: 1.1277 - accuracy: 0.6354 - val_loss: 0.3745 - val_accuracy: 0.9065
# Epoch 8/50
# 8/8 [==============================] - 1s 72ms/step - loss: 1.0425 - accuracy: 0.6428 - val_loss: 0.3300 - val_accuracy: 0.9175
# Epoch 9/50
# 8/8 [==============================] - 1s 72ms/step - loss: 1.0086 - accuracy: 0.6519 - val_loss: 0.2611 - val_accuracy: 0.9265
# Epoch 10/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.8907 - accuracy: 0.7077 - val_loss: 0.2645 - val_accuracy: 0.9206
# Epoch 11/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.8630 - accuracy: 0.7167 - val_loss: 0.2372 - val_accuracy: 0.9315
# Epoch 12/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.7379 - accuracy: 0.7720 - val_loss: 0.1945 - val_accuracy: 0.9382
# Epoch 13/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.7402 - accuracy: 0.7696 - val_loss: 0.1824 - val_accuracy: 0.9431
# Epoch 14/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6077 - accuracy: 0.8007 - val_loss: 0.1821 - val_accuracy: 0.9405
# Epoch 15/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.5954 - accuracy: 0.8161 - val_loss: 0.1628 - val_accuracy: 0.9479
# Epoch 16/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.6224 - accuracy: 0.8125 - val_loss: 0.1755 - val_accuracy: 0.9439
# Epoch 17/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.5584 - accuracy: 0.8353 - val_loss: 0.1697 - val_accuracy: 0.9462
# Epoch 18/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5724 - accuracy: 0.8066 - val_loss: 0.1475 - val_accuracy: 0.9510
# Epoch 19/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.5210 - accuracy: 0.8425 - val_loss: 0.1356 - val_accuracy: 0.9545
# Epoch 20/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.5399 - accuracy: 0.8212 - val_loss: 0.1388 - val_accuracy: 0.9556
# Epoch 21/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.4883 - accuracy: 0.8536 - val_loss: 0.1430 - val_accuracy: 0.9524
# Epoch 22/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.4975 - accuracy: 0.8580 - val_loss: 0.1276 - val_accuracy: 0.9580
# Epoch 23/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.4342 - accuracy: 0.8772 - val_loss: 0.1236 - val_accuracy: 0.9584
# Epoch 24/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3771 - accuracy: 0.8899 - val_loss: 0.0992 - val_accuracy: 0.9672
# Epoch 25/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.4217 - accuracy: 0.8657 - val_loss: 0.1084 - val_accuracy: 0.9638
# Epoch 26/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.3759 - accuracy: 0.8684 - val_loss: 0.1130 - val_accuracy: 0.9644
# Epoch 27/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.4026 - accuracy: 0.8704 - val_loss: 0.1151 - val_accuracy: 0.9630
# Epoch 28/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.3367 - accuracy: 0.9046 - val_loss: 0.1133 - val_accuracy: 0.9641
# Epoch 29/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.4098 - accuracy: 0.8783 - val_loss: 0.1354 - val_accuracy: 0.9563
# Epoch 30/50
# 8/8 [==============================] - 1s 75ms/step - loss: 0.3173 - accuracy: 0.9028 - val_loss: 0.1106 - val_accuracy: 0.9640
# Epoch 31/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3768 - accuracy: 0.8930 - val_loss: 0.1020 - val_accuracy: 0.9675
# Epoch 32/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2882 - accuracy: 0.9257 - val_loss: 0.0869 - val_accuracy: 0.9719
# Epoch 33/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3324 - accuracy: 0.8923 - val_loss: 0.0828 - val_accuracy: 0.9724
# Epoch 34/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2885 - accuracy: 0.9155 - val_loss: 0.1111 - val_accuracy: 0.9643
# Epoch 35/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3389 - accuracy: 0.9022 - val_loss: 0.0857 - val_accuracy: 0.9714
# Epoch 36/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2754 - accuracy: 0.9158 - val_loss: 0.0980 - val_accuracy: 0.9675
# Epoch 37/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.2727 - accuracy: 0.9128 - val_loss: 0.0848 - val_accuracy: 0.9711
# Epoch 38/50
# 8/8 [==============================] - 1s 71ms/step - loss: 0.3010 - accuracy: 0.9041 - val_loss: 0.0957 - val_accuracy: 0.9691
# Epoch 39/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2914 - accuracy: 0.9212 - val_loss: 0.0887 - val_accuracy: 0.9705
# Epoch 40/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2969 - accuracy: 0.9198 - val_loss: 0.0884 - val_accuracy: 0.9697
# Epoch 41/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2679 - accuracy: 0.9077 - val_loss: 0.0800 - val_accuracy: 0.9744
# Epoch 42/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3200 - accuracy: 0.9072 - val_loss: 0.0748 - val_accuracy: 0.9765
# Epoch 43/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.2727 - accuracy: 0.9128 - val_loss: 0.0739 - val_accuracy: 0.9758
# Epoch 44/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2230 - accuracy: 0.9399 - val_loss: 0.0757 - val_accuracy: 0.9750
# Epoch 45/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2311 - accuracy: 0.9331 - val_loss: 0.0727 - val_accuracy: 0.9767
# Epoch 46/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2232 - accuracy: 0.9242 - val_loss: 0.0734 - val_accuracy: 0.9767
# Epoch 47/50
# 8/8 [==============================] - 1s 73ms/step - loss: 0.2542 - accuracy: 0.9182 - val_loss: 0.0981 - val_accuracy: 0.9698
# Epoch 48/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.2463 - accuracy: 0.9112 - val_loss: 0.0800 - val_accuracy: 0.9723
# Epoch 49/50
# 8/8 [==============================] - 1s 74ms/step - loss: 0.2897 - accuracy: 0.9157 - val_loss: 0.0666 - val_accuracy: 0.9786
# Epoch 50/50
# 8/8 [==============================] - 1s 72ms/step - loss: 0.2654 - accuracy: 0.9195 - val_loss: 0.0620 - val_accuracy: 0.9796

# %%
# Plots for training and testing process: loss and accuracy

n_epochs = len(history.history['loss'])

plt.figure(0)
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
plt.legend(['train','validation'])

# %%
plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
print(x_train.reshape((len(x_train),img_rows, img_cols)).shape)
# see example augmentation images
fig = plt.figure(figsize=(12, 12))
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
         plt.subplot(330 + 1 + i)
         plt.imshow(X_batch[i].reshape((img_rows, img_cols)))
         plt.axis('off')
    plt.show()
    break
# Out:
# (1000, 28, 28)

# %%
# see example augmentation images
fig = plt.figure(figsize=(12, 12))

for i in range(0, 25):
    for X_batch, y_batch in datagen.flow(x_train[4:6], y_train[4:6], batch_size=1, shuffle=False):
         plt.subplot(5,5,i+1)
         plt.imshow(X_batch[0].reshape((img_rows, img_cols)), cmap=plt.cm.binary, interpolation='nearest')
         plt.axis('off')
         break

plt.show()

# %%
#visualize the digits
fig = plt.figure(figsize=(10, 10)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
# generate augmented plot
X_train, Y_train = datagen.flow(x_train,y_train, batch_size=100).next()
for i in range(100):
  ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
  ax.imshow(X_train[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')
  # label the image with the target value
  ax.text(0, 7, str(np.argmax(Y_train[i])))

# %%
# evaluate loaded model
scores_train = model.evaluate(x_train, y_train, verbose=0)
scores_test  = model.evaluate(x_test,  y_test,  verbose=0)

print("Accuracy Train: %.2f%% , Test: %.2f%% " % (scores_train[1]*100, scores_test[1]*100 ))
# Out:
# Accuracy Train: 99.10% , Test: 97.96%

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model.predict(x_test, verbose=2)

y_pred = np.argmax(Y_pred, axis=1)

y_test2 = np.argmax(y_test, axis=1)



#confusion matrix
cm = confusion_matrix(np.argmax(y_test,axis=1),y_pred)
print(cm)
# Out:
# 313/313 - 0s
# [[ 972    0    3    0    0    0    3    1    1    0]
#  [   2 1123    3    1    0    0    1    5    0    0]
#  [   0    0 1023    2    0    0    1    4    2    0]
#  [   0    0    2  982    0   16    0    5    3    2]
#  [   0    0    2    0  951    0    2    0    0   27]
#  [   0    2    0    3    0  883    2    1    1    0]
#  [   5    2    0    0    1    6  943    0    1    0]
#  [   0    1   12    2    2    0    0 1003    1    7]
#  [  12    1    5    0    1    3    5    0  937   10]
#  [   2    1    0    3    5    7    0    9    3  979]]

# %%
# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd


df_cm = pd.DataFrame(cm, range(10),range(10))
#                     range(num_classes),
#                  range(num_classes))
#plt.figure(figsize = (10,7))
plt.figure(2,figsize = (15,15) )
sn.set(font_scale=1.4) #for label size
sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
plt.show()

# %%
# use the model to predict the labels of the test data
predicted = model.predict(x_test)
expected = y_test0



# Plot the prediction
fig = plt.figure(figsize=(20, 20))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)


# plot the digits: each image is 28x28 pixels
for i in range(400):
    ax = fig.add_subplot(20, 20, i + 1, xticks=[], yticks=[])
    ax.imshow(x_test[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')

    # label the image with the target value
    if np.argmax(predicted[i]) == expected[i]:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='green')
    else:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='red')

# %%
# Creates the graph.png file

! pip3 install keras-visualizer
from keras_visualizer import visualizer  

#create the graph.png image
visualizer(model=model, view=True, format='png', filename='graph')

#show the graph
import matplotlib.image as mpimg
img = mpimg.imread('graph.png')
imgplot = plt.imshow(img,)
plt.show()
# Out:
# Requirement already satisfied: keras-visualizer in /usr/local/lib/python3.6/dist-packages (2.4)
